# %% [markdown]
# # Competitive Landscape - mySQL Database creation

# %% [markdown]
# First: information regarding school, comments and reviews from students

# %%
# dictionary with the schools evaluated in this project

schools = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035,
'brainstation' : 10571,
'designlab' : 10697,
'ux-design-institute' : 11150,
}

# importing libraries
import re
import pandas as pd
from pandas.io.json import json_normalize
import requests

# function to get the comments information
def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# Create a df with all the comments information
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard
# brainstation
# designlab
# ux-design-institute

# %%
#comments

comments['school_id'] = [schools[x] for x in comments['school']]

comments.rename(columns={'id': 'comment_id'}, inplace=True)

comments
# Out:
#     comment_id                     name  anonymous hostProgramName  \
# 0       276568  Guilherme golabek brein      False            None
# 1       276147          Charlotte Urvoy      False            None
# 2       275972                Anonymous       True            None
# 3       275872             Ahmad Khalaf      False            None
# 4       275855        Morgane Favchtein      False            None
# ..         ...                      ...        ...             ...
# 81      254128                    Joana      False    UX/UI Design
# 82      253451            Woobie Cheung      False    UX/UI Design
# 83      250795                Anonymous       True    UX/UI Design
# 84      246159           Paloma Sánchez      False    UX/UI Design
# 85      247136                Anonymous       True    UX/UI Design
#
#     graduatingYear  isAlumni                   jobTitle  \
# 0           2018.0     False           Senior Associate
# 1           2021.0     False             UX UI Designer
# 2           2021.0     False
# 3           2021.0     False           Product Designer
# 4           2021.0     False             UX UI Designer
# ..             ...       ...                        ...
# 81          2019.0      True                       None
# 82          2019.0      True                       None
# 83          2019.0      True           Project Manager
# 84          2019.0      True  eCommerce Product Manager
# 85          2018.0      True                       None
#
#                                            tagline  \
# 0                                 Improper billing
# 1                             Riche et pragmatique
# 2                               Amazing experience
# 3                      Intense but good experience
# 4                           Very nice experience !
# ..                                             ...
# 81  Professional Diploma in UX Design - Recommend!
# 82                    Good starting point into UX!
# 83               Professional Diploma in UX Design
# 84                        Diseño de procesos UX UI
# 85                    UX Design - Great Experience
#
#                                                  body  createdAt  ...  \
# 0   <span class="truncatable"><p></p><p>A year aft...  4/30/2021  ...
# 1   <span class="truncatable"><p></p><p>- La métho...  4/20/2021  ...
# 2   <span class="truncatable"><p></p><p>the UX/UI ...  4/17/2021  ...
# 3   <span class="truncatable"><p></p><p>When I sta...  4/15/2021  ...
# 4   <span class="truncatable"><p></p><p>The UX UI ...  4/14/2021  ...
# ..                                                ...        ...  ...
# 81  <span class="truncatable"><p>Just started this...  9/10/2019  ...
# 82  <span class="truncatable"><p>Like: <br>I learn...  8/21/2019  ...
# 83  <span class="truncatable"><p>These Course is o...  7/16/2019  ...
# 84  <span class="truncatable"><p>Me ha encantado! ...   4/4/2019  ...
# 85  <span class="truncatable"><p>This course is se...  3/14/2019  ...
#
#                               program             user overallScore comments  \
# 0           Web Development Part-Time  {'image': None}          1.0       []
# 1               UX/UI Design Bootcamp  {'image': None}          5.0       []
# 2               UX/UI Design Bootcamp  {'image': None}          4.0       []
# 3               UX/UI Design Bootcamp  {'image': None}          4.0       []
# 4               UX/UI Design Bootcamp  {'image': None}          4.3       []
# ..                                ...              ...          ...      ...
# 81                               None  {'image': None}          4.3       []
# 82                               None  {'image': None}          3.7       []
# 83  Professional Diploma in UX Design  {'image': None}          4.7       []
# 84  Professional Diploma in UX Design  {'image': None}          5.0       []
# 85  Professional Diploma in UX Design  {'image': None}          4.7       []
#
#    overall curriculum jobSupport  \
# 0      1.0        1.0        1.0
# 1      5.0        5.0        5.0
# 2      5.0        4.0        3.0
# 3      4.0        4.0        4.0
# 4      5.0        4.0        4.0
# ..     ...        ...        ...
# 81     5.0        5.0        3.0
# 82     4.0        4.0        3.0
# 83     5.0        5.0        4.0
# 84     5.0        5.0        5.0
# 85     5.0        4.0        5.0
#
#                                           review_body               school  \
# 0   A year after completing my course, ironhack co...             ironhack
# 1   - La méthode d'apprentissage est l'une des mei...             ironhack
# 2   the UX/UI bootcamp has been an amazing learnin...             ironhack
# 3   When I started I was a little disappointed but...             ironhack
# 4   The UX UI Design bootcamp is a great way to tr...             ironhack
# ..                                                ...                  ...
# 81  Just started this course a few weeks ago.They ...  ux-design-institute
# 82  Like: I learned how to do UX research step by ...  ux-design-institute
# 83  These Course is one of the best Courses out th...  ux-design-institute
# 84  Me ha encantado! Aprendí mucho sobre los proce...  ux-design-institute
# 85  This course is self paced and Springboard did ...  ux-design-institute
#
#    school_id
# 0      10828
# 1      10828
# 2      10828
# 3      10828
# 4      10828
# ..       ...
# 81     11150
# 82     11150
# 83     11150
# 84     11150
# 85     11150
#
# [3747 rows x 21 columns]

# %%
#importing more libraries
from pandas.io.json import json_normalize

# function to get the schools information
def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-4-9297fa760d64>:16: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# app-academy
# springboard
# brainstation
# designlab
# ux-design-institute

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id                       description  country.id   country.name  \
#  0  15704  San Francisco, CA, United States         1.0  United States
#  1  15705  New York City, NY, United States         1.0  United States
#  2  15862                            Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     13.0
#  1             US        34    New York           NY      new-york   1507.0
#  2            NaN         1      Online       Online        online      NaN
#
#         city.name   city.keyword       school  school_id
#  0  San Francisco  san-francisco  app-academy      10525
#  1            NYC  new-york-city  app-academy      10525
#  2            NaN            NaN  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ,
#        id        description  country.id    country.name country.abbrev  \
#  0  15935  New York City, NY         1.0   United States             US
#  1  15985    Toronto, Canada         2.0          Canada             CA
#  2  16010  Vancouver, Canada         2.0          Canada             CA
#  3  16909         Boston, MA         1.0   United States             US
#  4  16910        Chicago, IL         1.0   United States             US
#  5  16940             Online         NaN             NaN            NaN
#  6  17706          Miami, FL         1.0   United States             US
#  7  17731         London, UK        11.0  United Kingdom             GB
#
#     state.id        state.name state.abbrev  state.keyword  city.id  city.name  \
#  0      34.0          New York           NY       new-york   1507.0        NYC
#  1       NaN               NaN          NaN            NaN   1547.0    Toronto
#  2      71.0  British Columbia           BC                 31138.0  Vancouver
#  3      23.0     Massachusetts           MA  massachusetts     47.0     Boston
#  4      15.0          Illinois           IL       illinois     39.0    Chicago
#  5       1.0            Online       Online         online      NaN        NaN
#  6      11.0           Florida           FL        florida     31.0      Miami
#  7       NaN               NaN          NaN            NaN  31176.0     London
#
#      city.keyword        school  school_id
#  0  new-york-city  brainstation      10571
#  1        toronto  brainstation      10571
#  2      vancouver  brainstation      10571
#  3         boston  brainstation      10571
#  4        chicago  brainstation      10571
#  5            NaN  brainstation      10571
#  6          miami  brainstation      10571
#  7         london  brainstation      10571  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  15816      Online         1     Online       Online        online
#
#        school  school_id
#  0  designlab      10697  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16808      Online         1     Online       Online        online
#
#                  school  school_id
#  0  ux-design-institute      11150  ]

# %%
locations = pd.concat(locations_list)
locations.rename(columns={'id': 'location_id','country.id': 'country_id','country.name':'country_name',
                          'country.abbrev':'country_abbrev','city.id':'city_id','city.name':'city_name',
                          'city.keyword':'city_keyword','state.id':'state_id','state.name':'state_name',
                          'state.abbrev':'state_abbrev','state.keyword':'state_keyword'}, inplace=True)
locations
# Out:
#    location_id                       description  country_id    country_name  \
# 0        15901                   Berlin, Germany        57.0         Germany
# 1        16022               Mexico City, Mexico        29.0          Mexico
# 2        16086            Amsterdam, Netherlands        59.0     Netherlands
# 3        16088                 Sao Paulo, Brazil        42.0          Brazil
# 4        16109                     Paris, France        38.0          France
# 5        16375          Miami, FL, United States         1.0   United States
# 6        16376                     Madrid, Spain        12.0           Spain
# 7        16377                  Barcelona, Spain        12.0           Spain
# 8        16709                  Lisbon, Portugal        28.0        Portugal
# 9        17233                            Online         NaN             NaN
# 0        15704  San Francisco, CA, United States         1.0   United States
# 1        15705  New York City, NY, United States         1.0   United States
# 2        15862                            Online         NaN             NaN
# 0        16013                            Online         NaN             NaN
# 0        15935                 New York City, NY         1.0   United States
# 1        15985                   Toronto, Canada         2.0          Canada
# 2        16010                 Vancouver, Canada         2.0          Canada
# 3        16909                        Boston, MA         1.0   United States
# 4        16910                       Chicago, IL         1.0   United States
# 5        16940                            Online         NaN             NaN
# 6        17706                         Miami, FL         1.0   United States
# 7        17731                        London, UK        11.0  United Kingdom
# 0        15816                            Online         NaN             NaN
# 0        16808                            Online         NaN             NaN
#
#   country_abbrev  city_id      city_name   city_keyword  state_id  \
# 0             DE  31156.0         Berlin         berlin       NaN
# 1             MX  31175.0    Mexico City    mexico-city       NaN
# 2             NL  31168.0      Amsterdam      amsterdam       NaN
# 3             BR  31121.0      Sao Paulo      sao-paulo       NaN
# 4             FR  31136.0          Paris          paris       NaN
# 5             US     31.0          Miami          miami      11.0
# 6             ES  31052.0         Madrid         madrid       NaN
# 7             ES  31170.0      Barcelona      barcelona       NaN
# 8             PT  31075.0         Lisbon         lisbon       NaN
# 9            NaN      NaN            NaN            NaN       1.0
# 0             US     13.0  San Francisco  san-francisco       6.0
# 1             US   1507.0            NYC  new-york-city      34.0
# 2            NaN      NaN            NaN            NaN       1.0
# 0            NaN      NaN            NaN            NaN       1.0
# 0             US   1507.0            NYC  new-york-city      34.0
# 1             CA   1547.0        Toronto        toronto       NaN
# 2             CA  31138.0      Vancouver      vancouver      71.0
# 3             US     47.0         Boston         boston      23.0
# 4             US     39.0        Chicago        chicago      15.0
# 5            NaN      NaN            NaN            NaN       1.0
# 6             US     31.0          Miami          miami      11.0
# 7             GB  31176.0         London         london       NaN
# 0            NaN      NaN            NaN            NaN       1.0
# 0            NaN      NaN            NaN            NaN       1.0
#
#          state_name state_abbrev  state_keyword               school  \
# 0               NaN          NaN            NaN             ironhack
# 1               NaN          NaN            NaN             ironhack
# 2               NaN          NaN            NaN             ironhack
# 3               NaN          NaN            NaN             ironhack
# 4               NaN          NaN            NaN             ironhack
# 5           Florida           FL        florida             ironhack
# 6               NaN          NaN            NaN             ironhack
# 7               NaN          NaN            NaN             ironhack
# 8               NaN          NaN            NaN             ironhack
# 9            Online       Online         online             ironhack
# 0        California           CA     california          app-academy
# 1          New York           NY       new-york          app-academy
# 2            Online       Online         online          app-academy
# 0            Online       Online         online          springboard
# 0          New York           NY       new-york         brainstation
# 1               NaN          NaN            NaN         brainstation
# 2  British Columbia           BC                        brainstation
# 3     Massachusetts           MA  massachusetts         brainstation
# 4          Illinois           IL       illinois         brainstation
# 5            Online       Online         online         brainstation
# 6           Florida           FL        florida         brainstation
# 7               NaN          NaN            NaN         brainstation
# 0            Online       Online         online            designlab
# 0            Online       Online         online  ux-design-institute
#
#    school_id
# 0      10828
# 1      10828
# 2      10828
# 3      10828
# 4      10828
# 5      10828
# 6      10828
# 7      10828
# 8      10828
# 9      10828
# 0      10525
# 1      10525
# 2      10525
# 0      11035
# 0      10571
# 1      10571
# 2      10571
# 3      10571
# 4      10571
# 5      10571
# 6      10571
# 7      10571
# 0      10697
# 0      11150

# %%
courses = pd.concat(courses_list)
courses['courses_id'] = range(1, len(courses) + 1)
courses
# Out:
#                                           courses               school  \
# 0                         Cyber Security Bootcamp             ironhack
# 1                         Data Analytics Bootcamp             ironhack
# 2                        Data Analytics Part-Time             ironhack
# 3                           UX/UI Design Bootcamp             ironhack
# 4                          UX/UI Design Part-Time             ironhack
# 5                        Web Development Bootcamp             ironhack
# 6                       Web Development Part-Time             ironhack
# 0                                   Bootcamp Prep          app-academy
# 1              Software Engineer Track: In-Person          app-academy
# 2                                App Academy Open          app-academy
# 3                 Software Engineer Track: Online          app-academy
# 0                     Cyber Security Career Track          springboard
# 1                     Data Analytics Career Track          springboard
# 2                   Data Engineering Career Track          springboard
# 3                       Data Science Career Track          springboard
# 4                  Data Science Career Track Prep          springboard
# 5                          Introduction to Design          springboard
# 6       Machine Learning Engineering Career Track          springboard
# 7               Software Engineering Career Track          springboard
# 8   Software Engineering Career Track Prep Course          springboard
# 9                       UI/UX Design Career Track          springboard
# 10                                UX Career Track          springboard
# 0                Cybersecurity Certificate Course         brainstation
# 1               Data Analytics Certificate Course         brainstation
# 2                 Data Science Certificate Course         brainstation
# 3                                 Design Thinking         brainstation
# 4     Digital Leadership & Innovation Certificate         brainstation
# 5                               Digital Marketing         brainstation
# 6              iOS Development Certificate Course         brainstation
# 7             Machine Learning Certificate Course         brainstation
# 8           Product Management Certificate Course         brainstation
# 9                              Python Programming         brainstation
# 10     Search Engine Marketing Certificate Course         brainstation
# 11                         Social Media Marketing         brainstation
# 12      User Experience Design Certificate Course         brainstation
# 13       User Interface Design Certificate Course         brainstation
# 14             Web Development Certificate Course         brainstation
# 15                   Data Science Diploma Program         brainstation
# 16              Digital Marketing Diploma Program         brainstation
# 17         User Experience Design Diploma Program         brainstation
# 18                Web Development Diploma Program         brainstation
# 0                                      Design 101            designlab
# 1                                       UI Design            designlab
# 2                                      UX Academy            designlab
# 3                          UX Academy Foundations            designlab
# 4                          UX Research & Strategy            designlab
# 5                          UX: Interaction Design            designlab
# 0               Professional Diploma in UX Design  ux-design-institute
#
#     school_id  courses_id
# 0       10828           1
# 1       10828           2
# 2       10828           3
# 3       10828           4
# 4       10828           5
# 5       10828           6
# 6       10828           7
# 0       10525           8
# 1       10525           9
# 2       10525          10
# 3       10525          11
# 0       11035          12
# 1       11035          13
# 2       11035          14
# 3       11035          15
# 4       11035          16
# 5       11035          17
# 6       11035          18
# 7       11035          19
# 8       11035          20
# 9       11035          21
# 10      11035          22
# 0       10571          23
# 1       10571          24
# 2       10571          25
# 3       10571          26
# 4       10571          27
# 5       10571          28
# 6       10571          29
# 7       10571          30
# 8       10571          31
# 9       10571          32
# 10      10571          33
# 11      10571          34
# 12      10571          35
# 13      10571          36
# 14      10571          37
# 15      10571          38
# 16      10571          39
# 17      10571          40
# 18      10571          41
# 0       10697          42
# 1       10697          43
# 2       10697          44
# 3       10697          45
# 4       10697          46
# 5       10697          47
# 0       11150          48

# %%
badges = pd.concat(badges_list)
badges['schoolbadges_id'] = range(1, len(badges) + 1)
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description               school  \
# 0          <p>School offers fully online courses</p>             ironhack
# 1  <p>School publishes a third-party verified out...             ironhack
# 2  <p>School offers part-time and evening classes...             ironhack
# 0          <p>School offers fully online courses</p>          app-academy
# 1  <p>School offers part-time and evening classes...          app-academy
# 2             <p>School guarantees job placement</p>          app-academy
# 0          <p>School offers fully online courses</p>          springboard
# 1  <p>School offers part-time and evening classes...          springboard
# 2             <p>School guarantees job placement</p>          springboard
# 0          <p>School offers fully online courses</p>         brainstation
# 1  <p>School offers part-time and evening classes...         brainstation
# 0          <p>School offers fully online courses</p>            designlab
# 1  <p>School offers part-time and evening classes...            designlab
# 2             <p>School guarantees job placement</p>            designlab
# 0          <p>School offers fully online courses</p>  ux-design-institute
# 1  <p>School offers part-time and evening classes...  ux-design-institute
#
#    school_id  schoolbadges_id
# 0      10828                1
# 1      10828                2
# 2      10828                3
# 0      10525                4
# 1      10525                5
# 2      10525                6
# 0      11035                7
# 1      11035                8
# 2      11035                9
# 0      10571               10
# 1      10571               11
# 0      10697               12
# 1      10697               13
# 2      10697               14
# 0      11150               15
# 1      11150               16

# %%
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0                                    brainstation.io
# 0                                   trydesignlab.com
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>Springboard is an...
# 0  <span class="truncatable"><p>BrainStation is t...
# 0  <span class="truncatable"><p>Designlab teaches...
#
#                                              LogoUrl        school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...      ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...   app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...   springboard      11035
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  brainstation      10571
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     designlab      10697

# %% [markdown]
# # Creating our database in mySQL

# %%
#establish connection
import mysql.connector

# %%
cnx = mysql.connector.connect(user = "root", password = input('password:'),host="localhost")

# %%
cnx.is_connected()
# Out:
# True

# %%
cursor = cnx.cursor()
cursor

# %%
# Create database
query = ("""CREATE DATABASE competitive_landscape;""")
cursor.execute(query)

# %%
from sqlalchemy import create_engine

# %%
#Create a engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw=input('password:'),
                               db="competitive_landscape"))

# %%
# drop comments because there is a problem in the type of objects that are passed to Mysql
comments = comments.drop('comments', axis = 1)
# the same for the comments
comments = comments.drop('user', axis = 1)

# %%
#Create comments table in mysql with all data
comments.to_sql('comments', con = engine, if_exists = 'append', chunksize = 1000)

# %%
#Add Primary key in comments table
query = ("""ALTER TABLE competitive_landscape.comments ADD PRIMARY KEY(comment_id);""")
cursor.execute(query)

# %%
#Create courses table in mysql with all data
courses.to_sql('courses', con = engine, if_exists = 'append', chunksize = 1000)

# %%
#Add Primary key in courses table
query = ("""ALTER TABLE competitive_landscape.courses ADD PRIMARY KEY(courses_id);""")
cursor.execute(query)

# %%
#Create locations table in mysql with all data
locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 1000)

# %%
#Add Primary key in locations table
query = ("""ALTER TABLE competitive_landscape.locations ADD PRIMARY KEY(location_id);""")
cursor.execute(query)

# %%
#Create badges table in mysql with all data
badges.to_sql('badges', con = engine, if_exists = 'append', chunksize = 1000)

# %%
#Add Primary key in badges table
query = ("""ALTER TABLE competitive_landscape.badges ADD PRIMARY KEY(schoolbadges_id);""")
cursor.execute(query)

# %%
#Create schools table in mysql with all data
schools.to_sql('schools', con = engine, if_exists = 'append', chunksize = 1000)

# %%
#Add Primary key in schools table
query = ("""ALTER TABLE competitive_landscape.schools ADD PRIMARY KEY(school_id);""")
cursor.execute(query)

# %%
#CREATE THE FOREIGN KEYS

# %%
query = ("""ALTER TABLE competitive_landscape.courses ADD FOREIGN KEY (school_id) REFERENCES competitive_landscape.schools (school_id);""")
cursor.execute(query)

# %%
query = ("""ALTER TABLE competitive_landscape.badges ADD FOREIGN KEY (school_id) REFERENCES competitive_landscape.schools (school_id);""")
cursor.execute(query)

# %%
query = ("""ALTER TABLE competitive_landscape.locations ADD FOREIGN KEY (school_id) REFERENCES competitive_landscape.schools (school_id);""")
cursor.execute(query)

# %%
query = ("""ALTER TABLE competitive_landscape.comments ADD FOREIGN KEY (school_id) REFERENCES competitive_landscape.schools (school_id);""")
cursor.execute(query)

# %% [markdown]
# # Creating a additional table with information regarding each country

# %% [markdown]
# All the information presented in this table is available in: http://wdi.worldbank.org/tables

# %%
country_data = pd.read_csv('country_data.csv')
country_data
# Out:
#                           Country Name Country Code  \
# 0                                World          WLD
# 1                                World          WLD
# 2                                World          WLD
# 3                                World          WLD
# 4                                World          WLD
# ...                                ...          ...
# 13338                              NaN          NaN
# 13339                              NaN          NaN
# 13340                              NaN          NaN
# 13341  Data from database: WDI Central          NaN
# 13342         Last Updated: 04/26/2021          NaN
#
#                                              Series Name     Series Code  \
# 0                                      Population, total     SP.POP.TOTL
# 1                           Population growth (annual %)     SP.POP.GROW
# 2                                  Surface area (sq. km)  AG.SRF.TOTL.K2
# 3      Population density (people per sq. km of land ...     EN.POP.DNST
# 4      Poverty headcount ratio at national poverty li...     SI.POV.NAHC
# ...                                                  ...             ...
# 13338                                                NaN             NaN
# 13339                                                NaN             NaN
# 13340                                                NaN             NaN
# 13341                                                NaN             NaN
# 13342                                                NaN             NaN
#
#       Scale (Precision)  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0       Millions (0.00)        5280.11        6114.33        6921.87
# 1            Unit (0.0)           1.70           1.30           1.20
# 2       Thousands (0.0)      131634.50      131553.70      131784.80
# 3            Unit (0.0)          41.50          48.00          54.30
# 4            Unit (0.0)            NaN            NaN            NaN
# ...                 ...            ...            ...            ...
# 13338               NaN            NaN            NaN            NaN
# 13339               NaN            NaN            NaN            NaN
# 13340               NaN            NaN            NaN            NaN
# 13341               NaN            NaN            NaN            NaN
# 13342               NaN            NaN            NaN            NaN
#
#        2018 [YR2018]
# 0            7592.03
# 1               1.10
# 2          134542.70
# 3              58.40
# 4                NaN
# ...              ...
# 13338            NaN
# 13339            NaN
# 13340            NaN
# 13341            NaN
# 13342            NaN
#
# [13343 rows x 9 columns]

# %% [markdown]
# Lets clean the table

# %%
# columns without relevant information
country_data = country_data.drop('Country Code', axis = 1)
country_data = country_data.drop('Series Code', axis = 1)
country_data
# Out:
#                           Country Name  \
# 0                                World
# 1                                World
# 2                                World
# 3                                World
# 4                                World
# ...                                ...
# 13338                              NaN
# 13339                              NaN
# 13340                              NaN
# 13341  Data from database: WDI Central
# 13342         Last Updated: 04/26/2021
#
#                                              Series Name Scale (Precision)  \
# 0                                      Population, total   Millions (0.00)
# 1                           Population growth (annual %)        Unit (0.0)
# 2                                  Surface area (sq. km)   Thousands (0.0)
# 3      Population density (people per sq. km of land ...        Unit (0.0)
# 4      Poverty headcount ratio at national poverty li...        Unit (0.0)
# ...                                                  ...               ...
# 13338                                                NaN               NaN
# 13339                                                NaN               NaN
# 13340                                                NaN               NaN
# 13341                                                NaN               NaN
# 13342                                                NaN               NaN
#
#        1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2018 [YR2018]
# 0            5280.11        6114.33        6921.87        7592.03
# 1               1.70           1.30           1.20           1.10
# 2          131634.50      131553.70      131784.80      134542.70
# 3              41.50          48.00          54.30          58.40
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 13338            NaN            NaN            NaN            NaN
# 13339            NaN            NaN            NaN            NaN
# 13340            NaN            NaN            NaN            NaN
# 13341            NaN            NaN            NaN            NaN
# 13342            NaN            NaN            NaN            NaN
#
# [13343 rows x 7 columns]

# %%
#lets keep only rows with information that will be evaluated
condition = country_data[((country_data['Series Name'] != 'Population, total') &
                          (country_data['Series Name'] != 'Population growth (annual %)') & 
                          (country_data['Series Name'] != 'Primary completion rate, total (% of relevant age group)') &
                          (country_data['Series Name'] != 'School enrollment, primary (% gross)') & 
                          (country_data['Series Name'] != 'School enrollment, secondary (% gross)') &
                          (country_data['Series Name'] != 'School enrollment, primary and secondary (gross), gender parity index (GPI)') & 
                          (country_data['Series Name'] != 'Mobile cellular subscriptions (per 100 people)') &
                          (country_data['Series Name'] != 'Individuals using the Internet (% of population)') & 
                          (country_data['Series Name'] != 'High-technology exports (% of manufactured exports)'))]
condition

country_data_final = country_data.drop(condition.index, axis=0) # Step 2

country_data_final
# Out:
#       Country Name                                        Series Name  \
# 0            World                                  Population, total
# 1            World                       Population growth (annual %)
# 19           World  Primary completion rate, total (% of relevant ...
# 20           World               School enrollment, primary (% gross)
# 21           World             School enrollment, secondary (% gross)
# ...            ...                                                ...
# 13302     Zimbabwe             School enrollment, secondary (% gross)
# 13303     Zimbabwe  School enrollment, primary and secondary (gros...
# 13326     Zimbabwe     Mobile cellular subscriptions (per 100 people)
# 13327     Zimbabwe   Individuals using the Internet (% of population)
# 13328     Zimbabwe  High-technology exports (% of manufactured exp...
#
#       Scale (Precision)  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0       Millions (0.00)        5280.11        6114.33        6921.87
# 1            Unit (0.0)           1.70           1.30           1.20
# 19             Unit (0)          81.00          82.00          89.00
# 20           Unit (0.0)          99.80          98.80         103.20
# 21             Unit (0)          51.00          60.00          71.00
# ...                 ...            ...            ...            ...
# 13302          Unit (0)          43.00          45.00            NaN
# 13303          Unit (0)           1.00           1.00            NaN
# 13326        Unit (0.0)           0.00           2.20          60.60
# 13327        Unit (0.0)           0.00           0.40           6.40
# 13328          Unit (0)            NaN            NaN           2.00
#
#        2018 [YR2018]
# 0            7592.03
# 1               1.10
# 19             89.00
# 20            101.20
# 21             76.00
# ...              ...
# 13302            NaN
# 13303            NaN
# 13326          89.40
# 13327          27.10
# 13328           2.00
#
# [2106 rows x 7 columns]

# %%
#Lets rename de columns (mysql friendly)
country_data_final.rename(columns={'Country Name': 'country_name','Series Name': 'indicator',
                             'Scale (Precision)': 'unit','1990 [YR1990]': 'year_1990',
                             '2000 [YR2000]': 'year_2000','2010 [YR2010]': 'year_2010',
                             '2018 [YR2018]': 'year_2018'}, inplace=True)
country_data_final
# Out:
#       country_name                                          indicator  \
# 0            World                                  Population, total
# 1            World                       Population growth (annual %)
# 19           World  Primary completion rate, total (% of relevant ...
# 20           World               School enrollment, primary (% gross)
# 21           World             School enrollment, secondary (% gross)
# ...            ...                                                ...
# 13302     Zimbabwe             School enrollment, secondary (% gross)
# 13303     Zimbabwe  School enrollment, primary and secondary (gros...
# 13326     Zimbabwe     Mobile cellular subscriptions (per 100 people)
# 13327     Zimbabwe   Individuals using the Internet (% of population)
# 13328     Zimbabwe  High-technology exports (% of manufactured exp...
#
#                   unit  year_1990  year_2000  year_2010  year_2018
# 0      Millions (0.00)    5280.11    6114.33    6921.87    7592.03
# 1           Unit (0.0)       1.70       1.30       1.20       1.10
# 19            Unit (0)      81.00      82.00      89.00      89.00
# 20          Unit (0.0)      99.80      98.80     103.20     101.20
# 21            Unit (0)      51.00      60.00      71.00      76.00
# ...                ...        ...        ...        ...        ...
# 13302         Unit (0)      43.00      45.00        NaN        NaN
# 13303         Unit (0)       1.00       1.00        NaN        NaN
# 13326       Unit (0.0)       0.00       2.20      60.60      89.40
# 13327       Unit (0.0)       0.00       0.40       6.40      27.10
# 13328         Unit (0)        NaN        NaN       2.00       2.00
#
# [2106 rows x 7 columns]

# %%
#Add a column with a unique value
country_data_final['count_indicator_id'] = range(1, len(country_data1) + 1)
country_data_final
# Out:
#       country_name                                          indicator  \
# 0            World                                  Population, total
# 1            World                       Population growth (annual %)
# 19           World  Primary completion rate, total (% of relevant ...
# 20           World               School enrollment, primary (% gross)
# 21           World             School enrollment, secondary (% gross)
# ...            ...                                                ...
# 13302     Zimbabwe             School enrollment, secondary (% gross)
# 13303     Zimbabwe  School enrollment, primary and secondary (gros...
# 13326     Zimbabwe     Mobile cellular subscriptions (per 100 people)
# 13327     Zimbabwe   Individuals using the Internet (% of population)
# 13328     Zimbabwe  High-technology exports (% of manufactured exp...
#
#                   unit  year_1990  year_2000  year_2010  year_2018  \
# 0      Millions (0.00)    5280.11    6114.33    6921.87    7592.03
# 1           Unit (0.0)       1.70       1.30       1.20       1.10
# 19            Unit (0)      81.00      82.00      89.00      89.00
# 20          Unit (0.0)      99.80      98.80     103.20     101.20
# 21            Unit (0)      51.00      60.00      71.00      76.00
# ...                ...        ...        ...        ...        ...
# 13302         Unit (0)      43.00      45.00        NaN        NaN
# 13303         Unit (0)       1.00       1.00        NaN        NaN
# 13326       Unit (0.0)       0.00       2.20      60.60      89.40
# 13327       Unit (0.0)       0.00       0.40       6.40      27.10
# 13328         Unit (0)        NaN        NaN       2.00       2.00
#
#        count_indicator_id
# 0                       1
# 1                       2
# 19                      3
# 20                      4
# 21                      5
# ...                   ...
# 13302                2102
# 13303                2103
# 13326                2104
# 13327                2105
# 13328                2106
#
# [2106 rows x 8 columns]

# %%
#Create country_data table in mysql with all data
country_data_final.to_sql('country_data', con = engine, if_exists = 'append', chunksize = 1000)

# %%
#Add Primary key in country_data table
query = ("""ALTER TABLE competitive_landscape.country_data ADD PRIMARY KEY(count_indicator_id);""")
cursor.execute(query)
